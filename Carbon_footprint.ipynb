# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib #collection of functions for scientific and publication-ready visualization
import matplotlib.pyplot as plt # for plotting
# %matplotlib inline
pd.set_option('display.max_columns', None)

#USA emmissions data measured in million metric tons of carbon dioxide
df_gen = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/usa%20co2%20emmissios%201960%20to%202020.csv') #usa co2 emmissions 1960-2018
df_elec = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/electricity%20-%20Sheet1.csv') #Electricity Emissions by State (1980 - 2018)
df_trans = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/transportation%20-%20Sheet1.csv') #Transportation Emissions by State (1980 - 2018)
df_indus = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/industrial%20-%20Sheet1.csv') #Industrial Emissions by State (1980 - 2018)
#df_state_half = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/general%20-%20Tab2.csv') #State energy-related carbon dioxide emissions by year, adjusted (2000–2018)
df_coal = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/coal%20-%20Sheet1.csv') #Coal Emissions by State (1980 - 2018)
df_com = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/commercial%20-%20Sheet1.csv') #Commercial Emissions by State (1980 - 2018)
df_lng = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/naturalgas%20-%20Sheet1.csv') #Natural Gas Emissions by State (1980 - 2018)
df_pet = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/petroleum%20-%20Sheet1.csv') #Petroleum Emissions by State (1980 - 2018)
df_res = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/residential%20-%20Sheet1.csv') #Residential Emissions by State (1980 - 2018)



#Economic uncertainties
#df_gdp = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/GDP.csv') #GDP
df_gdp_cap = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/GDP%20per%20cap.csv') #GDP per cap
df_exp = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/exports.csv') #Exports
df_imp = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/imports.csv') #Imports
df_pop = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/population.csv') #Population
df_inf = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/inflation.csv') #Inflation
df_int = pd.read_csv('https://raw.githubusercontent.com/chuka19952/carbon-footprint/main/interest%20rate.csv') #Interest rate 1961-2020

# %% [markdown]
# There are 15 datasets to be used in total;
#
# 9 emmission datasets capturing contributions of co2 froem different sectors of the economic and 6 economic uncertainties that may affect the emissions rates directly or indirectly.

# %%
df_gen.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                            Indicator Name  Indicator Code        1960  \
# 0  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# 4  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.100835
#
#          1961        1962        1963        1964        1965        1966  \
# 0  208.837879  226.081890  214.785217  207.626699  185.213644  172.158729
# 1    0.922474    0.930816    0.940570    0.996033    1.047280    1.033908
# ...

# %%
# Drop last column
df_gen.drop(['Country Code', 'Indicator Name', 'Indicator Code','Unnamed: 65'], axis=1, inplace=True)
df_gen.shape

#transforming date columns to to one columns "year"

df_gen2 = pd.melt(df_gen, id_vars= ['Country Name'], 
                  var_name="Year", value_name="emmission value")


#filling empty values with zeros

df_gen2['emmission value'] = df_gen2['emmission value'].fillna(0)


#extracting the united states data only

ame_gen = df_gen2[df_gen2['Country Name'] == 'United States']
ame_gen.shape

# %%
# Using graph_objects
import plotly.graph_objects as go

fig = go.Figure([go.Scatter(x=ame_gen['Year'], y=ame_gen['emmission value'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="717deeb5-00b1-45e0-a348-5a8dfb3eb1ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("717deeb5-00b1-45e0-a348-5a8dfb3eb1ac")) {
#                     Plotly.newPlot(
#                         '717deeb5-00b1-45e0-a348-5a8dfb3eb1ac',
# ...

# %%
with sns.axes_style('white'):
    g = sns.factorplot("emmission value", data=df_gen2, aspect=4.0, kind='count',
                       hue='Country Name')
    g.set_ylabels('Emmission value')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
